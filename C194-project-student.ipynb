# %%
print("Name : ")
print("We will be cleaning the big data and make a comparison to show who has a healthier heart smokers OR non smokers, uisng a line graph")
print("Also we will be deriviring which age group has the high chances of coronary heart disease in 10 years")
# Out:
# Name :
# We will be cleaning the big data and make a comparison to show who has a healthier heart smokers OR non smokers, uisng a line graph
# Also we will be deriviring which age group has the high chances of coronary heart disease in 10 years

# %% [markdown]
# # Task 1 - Plot a line graph to show the difference between heart rate of smokers and non smokers

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

health = pd.read_csv('framingham.csv')
health
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
nonsmoker=health.loc[health['currentSmoker'] == 0]
nonsmoker
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 5        0   43        2.0              0         0.0     0.0
# 6        0   63        1.0              0         0.0     0.0
# 8        1   52        1.0              0         0.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4226     1   58        1.0              0         0.0     0.0
# 4228     0   50        1.0              0         0.0     0.0
# 4231     1   58        3.0              0         0.0     0.0
# 4232     1   68        1.0              0         0.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
groupby_nonsmoker=nonsmoker.groupby('age')['heartRate'].mean().reset_index()
groupby_nonsmoker
# Out:
#     age  heartRate
# 0    33  76.000000
# 1    34  74.000000
# 2    35  74.789474
# 3    36  74.216216
# 4    37  76.027778
# 5    38  72.232143
# 6    39  76.239437
# 7    40  77.885714
# 8    41  73.083333
# 9    42  75.042857
# 10   43  75.050000
# 11   44  73.746032
# 12   45  77.333333
# 13   46  77.038961
# 14   47  75.173077
# 15   48  75.176471
# 16   49  73.868852
# 17   50  75.791045
# 18   51  74.200000
# 19   52  76.560440
# 20   53  77.125000
# 21   54  74.437500
# 22   55  74.305263
# 23   56  73.397059
# 24   57  74.027778
# 25   58  75.343750
# 26   59  74.197368
# 27   60  75.342857
# 28   61  73.770270
# 29   62  74.202899
# 30   63  75.129870
# 31   64  76.469697
# 32   65  74.200000
# 33   66  80.714286
# 34   67  73.448276
# 35   68  80.166667
# 36   69  80.500000
# 37   70  64.000000

# %%
smoker=health.loc[health['currentSmoker'] == 0]
smoker
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 5        0   43        2.0              0         0.0     0.0
# 6        0   63        1.0              0         0.0     0.0
# 8        1   52        1.0              0         0.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4226     1   58        1.0              0         0.0     0.0
# 4228     0   50        1.0              0         0.0     0.0
# 4231     1   58        3.0              0         0.0     0.0
# 4232     1   68        1.0              0         0.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
groupby_smoker=nonsmoker.groupby('age')['heartRate'].mean().reset_index()
groupby_smoker
# Out:
#     age  heartRate
# 0    33  76.000000
# 1    34  74.000000
# 2    35  74.789474
# 3    36  74.216216
# 4    37  76.027778
# 5    38  72.232143
# 6    39  76.239437
# 7    40  77.885714
# 8    41  73.083333
# 9    42  75.042857
# 10   43  75.050000
# 11   44  73.746032
# 12   45  77.333333
# 13   46  77.038961
# 14   47  75.173077
# 15   48  75.176471
# 16   49  73.868852
# 17   50  75.791045
# 18   51  74.200000
# 19   52  76.560440
# 20   53  77.125000
# 21   54  74.437500
# 22   55  74.305263
# 23   56  73.397059
# 24   57  74.027778
# 25   58  75.343750
# 26   59  74.197368
# 27   60  75.342857
# 28   61  73.770270
# 29   62  74.202899
# 30   63  75.129870
# 31   64  76.469697
# 32   65  74.200000
# 33   66  80.714286
# 34   67  73.448276
# 35   68  80.166667
# 36   69  80.500000
# 37   70  64.000000

# %%
#Plot a line graph to show the heart rate of smokers vs non smokers
plt.figure(figsize=(12,8))

plt.plot(groupby_nonsmoker['age'],groupby_nonsmoker['heartRate'], label='Heart Rate of Nonsmokers',linewidth=3)
plt.plot(groupby_smoker['age'],groupby_smoker['heartRate'], label='Heart Rate of Smokers',linewidth=3)

plt.xlabel('Age')
plt.ylabel('Heart Rate')
plt.title('Heart Rate of Smokers and Nonsmokers')
plt.legend()
plt.show()

# %% [markdown]
# Conslusion -

# %% [markdown]
# # Task 2 - Which age group have high chances of having coronary heart disease in 10 years

# %%
health2 = pd.read_csv('framingham.csv')
coronary_heart_disease=health2.loc[health2['TenYearCHD'] == 1]
coronary_heart_disease
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 3        0   61        3.0              1        30.0     0.0
# 6        0   63        1.0              0         0.0     0.0
# 15       0   38        2.0              1        20.0     0.0
# 17       0   46        2.0              1        20.0     0.0
# 25       1   47        4.0              1        20.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4221     1   50        1.0              0         0.0     0.0
# 4223     1   56        4.0              0         0.0     1.0
# 4226     1   58        1.0              0         0.0     0.0
# 4232     1   68        1.0              0         0.0     0.0
# 4233     1   50        1.0              1         1.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 3                   0             1         0    225.0  150.0   95.0  28.58
# ...

# %%
group_age=coronary_heart_disease.groupby('age')['TenYearCHD'].count().reset_index()
group_age
# Out:
#     age  TenYearCHD
# 0    35           2
# 1    36           3
# 2    37           4
# 3    38           8
# 4    39           6
# 5    40          15
# 6    41          11
# 7    42          14
# 8    43          13
# 9    44          16
# 10   45          14
# 11   46          16
# 12   47          23
# 13   48          21
# 14   49          24
# 15   50          23
# 16   51          29
# 17   52          32
# 18   53          23
# 19   54          18
# 20   55          24
# 21   56          27
# 22   57          26
# 23   58          31
# 24   59          30
# 25   60          26
# 26   61          25
# 27   62          25
# 28   63          32
# 29   64          21
# 30   65          20
# 31   66          15
# 32   67          17
# 33   68           8
# 34   69           1
# 35   70           1

# %%
plt.figure(figsize=(12,8))

plt.scatter(group_age['age'],group_age['TenYearCHD'], label='People with 10 years of CHD',color='red',alpha=0.5,
            s=group_age['TenYearCHD']*50)

plt.xlabel('Age')
plt.ylabel('People with 10 years of CHD')
plt.title('Different ages with 10 years of CHD')
plt.legend()
plt.show()

# %% [markdown]
# Conslusion -
